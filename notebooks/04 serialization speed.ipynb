# %% [markdown]
# # Serialization speed of Python `bytes`
#
# In this example, we measure how much time it takes to serialize up to 1GB of random bytes, repeating the test 10 times. The type of the serialized Python variable has type `bytes`. Interesting fact: [SQLite is faster than writing directly to filesystem](https://www.sqlite.org/fasterthanfs.html).

# %%
import os

from mltraq import Run, Sequence, create_experiment


def eval_persist(run: Run):
    """
    Measure the time required to persist and load
    an experiment with a run holding a blob of
    up to 1GB of randomness.
    """

    e = create_experiment()
    run.fields.log = Sequence()
    e.fields.blob = os.urandom(run.params.n_bytes)

    run.fields.log.append(tag="a")
    e.persist()
    run.fields.log.append(tag="b")
    e.reload()
    run.fields.log.append(tag="c")

    durations = run.fields.log.df().pivot_table(index="tag", values="timestamp")["timestamp"]
    run.fields.n_bytes = run.params.n_bytes
    run.fields.duration_persist = durations.b - durations.a
    run.fields.duration_load = durations.c - durations.b


e = create_experiment()

# We vary `i` to average on 10 runs per configuration,
# the number of written bytes ranges from 10B to 10GB
e.add_runs(
    i=range(10),
    n_bytes=[10**i for i in range(10)],
)

# Execute experiment, runs executed in foreground
e.execute(eval_persist, n_jobs=1)

# Overview of runs
e.runs
# Out:
#   1%|1         | 1/100 [00:02<04:32,  2.75s/it]
# {UUID('1ee14e4b-c2a9-4584-a9db-813d1ba2af96'): <mltraq.run.Run at 0x11e80ceb0>,
#  UUID('294117fa-dec2-4ab8-86c4-9a8b19b70ba7'): <mltraq.run.Run at 0x11e80ce40>,
#  UUID('ece8af3b-b40f-4e5f-8673-b1a77b94b9b1'): <mltraq.run.Run at 0x11e80cc80>,
#  UUID('ab6609a3-912e-4917-bf02-f41e7055587b'): <mltraq.run.Run at 0x11e80cdd0>,
#  UUID('1509a652-5bac-4eda-b56a-0b911760979b'): <mltraq.run.Run at 0x11e80cf20>,
#  UUID('c13c01c3-a417-4890-a701-2ae06284bb82'): <mltraq.run.Run at 0x11e80cf90>,
#  UUID('69812adf-8d98-4875-80b6-d8c46def51a6'): <mltraq.run.Run at 0x11e80d000>,
#  UUID('5584b82b-af1a-45bf-8187-e6a160123d32'): <mltraq.run.Run at 0x11e80d070>,
#  UUID('eb9a5084-9073-48ea-aa50-ee32e25a7ce5'): <mltraq.run.Run at 0x11e80d0e0>,
#  UUID('ecb1bae4-138b-4abd-a142-0b8c2461353d'): <mltraq.run.Run at 0x11e80d150>,
#  UUID('f3931356-82dd-4eb4-b4a3-7c4c3832d70d'): <mltraq.run.Run at 0x11e80d1c0>,
#  UUID('467bde9c-1171-4b4f-ac18-f6b25e26e9c1'): <mltraq.run.Run at 0x11e80d230>,
#  UUID('ad707b6f-8651-42c5-ba19-5b21bc4dc055'): <mltraq.run.Run at 0x11e80d2a0>,
#  UUID('4c729faf-910e-4926-8d45-fe177c3f41bd'): <mltraq.run.Run at 0x11e80d310>,
#  UUID('8821eac0-7295-4b6b-8228-e555aeaff44b'): <mltraq.run.Run at 0x11e80d380>,
#  UUID('66639c88-f678-45c3-9031-4da02f493d35'): <mltraq.run.Run at 0x11e80d3f0>,
#  UUID('238d3282-9130-45e1-8662-6ca27bd6a0fc'): <mltraq.run.Run at 0x11e80d460>,
#  UUID('366987e0-1e46-47a9-a52a-9e8e63b2967c'): <mltraq.run.Run at 0x11e80d4d0>,
#  UUID('4e5fc8ca-665d-4dcf-9626-fcd3766b5131'): <mltraq.run.Run at 0x11e80d540>,
#  UUID('ad288d2f-3744-4946-9b96-05804d66f75b'): <mltraq.run.Run at 0x11e80d5b0>,
#  UUID('b0c5a943-e90b-4849-9e14-d2ceb46ab282'): <mltraq.run.Run at 0x11e80d620>,
#  UUID('1d871d68-7c25-47cf-925d-80b6186601b5'): <mltraq.run.Run at 0x11e80d690>,
#  UUID('ad430711-de50-4904-837b-deac5a52274f'): <mltraq.run.Run at 0x11e80d700>,
#  UUID('1f563071-f820-4fcc-865d-89e993e0ebc7'): <mltraq.run.Run at 0x11e80d770>,
#  UUID('37735809-deb6-4e30-a8cf-3625f62078ae'): <mltraq.run.Run at 0x11e80d7e0>,
#  UUID('99cdba21-ae55-448a-844b-834899f06825'): <mltraq.run.Run at 0x11e80d850>,
#  UUID('e17c293b-dc00-4eb1-af4e-eaef0cf3cffb'): <mltraq.run.Run at 0x11e80d8c0>,
#  UUID('abcec639-ec70-49ee-9ec8-c90ea98ffba2'): <mltraq.run.Run at 0x11e80d930>,
#  UUID('a82fa403-ed64-4990-8ac8-974bba9b2904'): <mltraq.run.Run at 0x11e80d9a0>,
#  UUID('86ab5dd2-6c98-4bbf-8208-c3f4646b7ebe'): <mltraq.run.Run at 0x11e80da10>,
#  UUID('83237c2a-c2e7-449c-9cf2-365977abb062'): <mltraq.run.Run at 0x11e80da80>,
#  UUID('bfd6af16-ca91-4433-beac-de16248463ce'): <mltraq.run.Run at 0x11e80daf0>,
#  UUID('fc21c5e2-174e-4bad-bf1e-865fc926edda'): <mltraq.run.Run at 0x11e80db60>,
#  UUID('bb1d5575-5516-4e19-b7ec-2c57a157b784'): <mltraq.run.Run at 0x11e80dbd0>,
#  UUID('c52c660e-ba41-4efa-b8fc-07fbd2f0c06e'): <mltraq.run.Run at 0x11e80dc40>,
#  UUID('95f77bff-6829-45bd-b546-d74868a12546'): <mltraq.run.Run at 0x11e80dcb0>,
#  UUID('d6e37ec3-1111-447a-9f6b-a318c86ed973'): <mltraq.run.Run at 0x11e80dd20>,
#  UUID('8adf09f2-8035-4117-b696-93768ddefde2'): <mltraq.run.Run at 0x11e80dd90>,
#  UUID('3e34cffb-86d0-40ed-abf2-b07d816ea609'): <mltraq.run.Run at 0x11e80de00>,
#  UUID('fcd46e78-db5f-42c1-8495-1c8e6a7c3129'): <mltraq.run.Run at 0x11e80de70>,
#  UUID('59a10f1f-63b6-4d96-b35a-0ed8158976f2'): <mltraq.run.Run at 0x11e80dee0>,
#  UUID('3034eac9-d950-414a-8018-a04f7a065d66'): <mltraq.run.Run at 0x11e80df50>,
#  UUID('fa8b9b11-4f13-4425-8308-4508f11eb994'): <mltraq.run.Run at 0x11e80dfc0>,
#  UUID('763e3cb9-8802-43e1-8043-568b3b3dc827'): <mltraq.run.Run at 0x11e80e030>,
#  UUID('7d3a2077-61e5-4f7c-8b4e-fcbf7a0540f8'): <mltraq.run.Run at 0x11e80e0a0>,
#  UUID('d9ea3db2-4ddd-4967-a009-647e1b0098bd'): <mltraq.run.Run at 0x11e80e110>,
#  UUID('9c026e93-6397-41b7-988b-740899610ef2'): <mltraq.run.Run at 0x11e80e180>,
#  UUID('e866179a-7965-4fdd-bb24-a3dfdc74a909'): <mltraq.run.Run at 0x11e80e1f0>,
#  UUID('8c10faa9-0afb-4a1b-aff1-dec53977de24'): <mltraq.run.Run at 0x11e80e260>,
#  UUID('891a32b1-e6d2-4f7e-8225-22adcc1f9899'): <mltraq.run.Run at 0x11e80e2d0>,
#  UUID('a0aed4be-0018-47b6-a579-45bb7927512d'): <mltraq.run.Run at 0x11e80e340>,
#  UUID('9188a2ef-6bb8-4b37-8b21-5fe76f47f80f'): <mltraq.run.Run at 0x11e80e3b0>,
#  UUID('fe706c83-9d23-4fea-bafe-ad551000a2a3'): <mltraq.run.Run at 0x11e80e420>,
#  UUID('e301b9dd-237c-4949-acfe-c291507ddb7d'): <mltraq.run.Run at 0x11e80e490>,
#  UUID('d3780ab1-04c4-4078-a1d4-2706717e89a3'): <mltraq.run.Run at 0x11e80e500>,
#  UUID('c4ec08c9-6f5d-4364-a666-f7ec764929cc'): <mltraq.run.Run at 0x11e80e570>,
#  UUID('eb4df4c4-dc2f-4700-b783-fe86a83dc46e'): <mltraq.run.Run at 0x11e80e5e0>,
#  UUID('412bb4a7-16ae-4c3b-a408-b92edd04a3a5'): <mltraq.run.Run at 0x11e80e650>,
#  UUID('36b37662-93de-4321-97a3-96a6a2de6c90'): <mltraq.run.Run at 0x11e80e6c0>,
#  UUID('1436eaa7-5c99-434d-b659-7db149fe0a90'): <mltraq.run.Run at 0x11e80e730>,
#  UUID('6bce6fa9-fb65-4716-b41b-e8deb9627306'): <mltraq.run.Run at 0x11e80e7a0>,
#  UUID('2def3354-c946-47bb-b941-7a87ab04cde7'): <mltraq.run.Run at 0x11e80e810>,
#  UUID('67fd7f20-98cb-4a09-9360-32ef9c34f702'): <mltraq.run.Run at 0x11e80e880>,
#  UUID('8f11e8e3-6890-436b-97e1-0c79b58791f1'): <mltraq.run.Run at 0x11e80e8f0>,
#  UUID('85b61b31-ca4c-46a8-8c06-625b835c9b1c'): <mltraq.run.Run at 0x11e80e960>,
#  UUID('508d7ccd-fe22-432d-85d9-4ceaf5855f02'): <mltraq.run.Run at 0x11e80e9d0>,
#  UUID('2c74b5ac-55ee-4a25-a204-2038acf41437'): <mltraq.run.Run at 0x11e80ea40>,
#  UUID('feb107f0-f141-4f5a-a30d-67f15777208d'): <mltraq.run.Run at 0x11e80eab0>,
#  UUID('2469b5e7-2331-49c7-b3a2-67f3d31402cd'): <mltraq.run.Run at 0x11e80eb20>,
#  UUID('5e00f89f-79a0-4e24-8a50-5fb0131223d1'): <mltraq.run.Run at 0x11e80eb90>,
#  UUID('055dd938-93ee-468b-8fa1-5104e78d1121'): <mltraq.run.Run at 0x11e80ec00>,
#  UUID('01dd80e2-76b5-4732-a609-c45260612fd8'): <mltraq.run.Run at 0x11e80ec70>,
#  UUID('356c6832-24da-4ee0-9eb8-aec3643104b0'): <mltraq.run.Run at 0x11e80ece0>,
#  UUID('1be5afe3-b428-4bb4-b363-2ff547177856'): <mltraq.run.Run at 0x11e80ed50>,
#  UUID('cbeda404-1c11-4406-b13d-9b1d21ce1816'): <mltraq.run.Run at 0x11e80edc0>,
#  UUID('1d46794d-a3bb-417c-9b28-7fce77916002'): <mltraq.run.Run at 0x11e80ee30>,
#  UUID('dc337196-9e2e-4eba-aee9-1cbc598343f1'): <mltraq.run.Run at 0x11e80eea0>,
#  UUID('b736951b-f485-4341-94bd-27ae5d136686'): <mltraq.run.Run at 0x11e80ef10>,
#  UUID('bdeebe17-fd9f-48b8-9c27-67c604872130'): <mltraq.run.Run at 0x11e80ef80>,
#  UUID('38607a80-ba74-4864-9724-6f5cd5f67f16'): <mltraq.run.Run at 0x11e80eff0>,
#  UUID('111177cb-0542-4005-b97b-1a809fe15b38'): <mltraq.run.Run at 0x11e80f060>,
#  UUID('a2d55d56-1bfb-45c6-99d5-a5d475b72c3d'): <mltraq.run.Run at 0x11e80f0d0>,
#  UUID('24de5bb5-4ae3-4fed-b21f-375c42d3d8ce'): <mltraq.run.Run at 0x11e80f140>,
#  UUID('6cedf8e4-1367-4d47-b4c7-140d3a282ce8'): <mltraq.run.Run at 0x11e80f1b0>,
#  UUID('95436488-68f1-40d8-a9b5-abfbbc9a9010'): <mltraq.run.Run at 0x11e80f220>,
#  UUID('9e9160c4-a77b-450c-959e-fc2d90750b23'): <mltraq.run.Run at 0x11e80f290>,
#  UUID('40c1984c-0078-4fce-81d4-5b35c2f384bb'): <mltraq.run.Run at 0x11e80f300>,
#  UUID('af7538ba-393e-448e-8e97-a6e265ff3047'): <mltraq.run.Run at 0x11e80f370>,
#  UUID('7677cc54-0c92-4035-b11d-80840d2918bc'): <mltraq.run.Run at 0x11e80f3e0>,
#  UUID('f95cdba3-9062-4b70-b95c-7f6ffaa6cf16'): <mltraq.run.Run at 0x11e80f450>,
#  UUID('645856db-7b0c-45a6-a10b-48ab692a9f80'): <mltraq.run.Run at 0x11e80f4c0>,
#  UUID('51da2463-6ad1-43ec-b5e2-50e16a28bd49'): <mltraq.run.Run at 0x11e80f530>,
#  UUID('f634b5ce-87f1-4c83-a779-bfe03f798312'): <mltraq.run.Run at 0x11e80f5a0>,
#  UUID('0b9cd511-ecaa-4913-b791-feec853081b7'): <mltraq.run.Run at 0x11e80f610>,
#  UUID('6b8b575e-17ac-4c36-8860-3a669ddde295'): <mltraq.run.Run at 0x11e80f680>,
#  UUID('91044079-60ce-4b38-af91-d7091e8746bd'): <mltraq.run.Run at 0x11e80f6f0>,
#  UUID('69295394-0055-4072-b7a1-28af968e17d1'): <mltraq.run.Run at 0x11e80f760>,
#  UUID('628bbf5b-4408-4998-a64a-7934a72e9996'): <mltraq.run.Run at 0x11e80f7d0>,
#  UUID('d7b863a2-d118-4cab-b9ad-c9e8ac59e78a'): <mltraq.run.Run at 0x11e80f840>,
#  UUID('386bf9af-b3b9-49df-8be3-64e9d3d4e03f'): <mltraq.run.Run at 0x11e80f8b0>}

# %%
# "Persist" elapsed time
e.runs.df().groupby("n_bytes").duration_persist.mean()
# Out:
# n_bytes
# 1            0 days 00:00:00.002832947
# 10           0 days 00:00:00.008128281
# 100          0 days 00:00:00.009354188
# 1000         0 days 00:00:00.002717363
# 10000        0 days 00:00:00.003744972
# 100000       0 days 00:00:00.023576780
# 1000000      0 days 00:00:00.008609689
# 10000000     0 days 00:00:00.007717964
# 100000000    0 days 00:00:00.062335795
# 1000000000   0 days 00:00:00.770540262
# Name: duration_persist, dtype: timedelta64[ns]

# %%
# "Reload" elapsed time
e.runs.df().groupby("n_bytes").duration_load.mean()
# Out:
# n_bytes
# 1            0 days 00:00:00.000568806
# 10           0 days 00:00:00.000534912
# 100          0 days 00:00:00.000547814
# 1000         0 days 00:00:00.000554009
# 10000        0 days 00:00:00.000543616
# 100000       0 days 00:00:00.000590899
# 1000000      0 days 00:00:00.000763033
# 10000000     0 days 00:00:00.001858662
# 100000000    0 days 00:00:00.029299404
# 1000000000   0 days 00:00:00.458244556
# Name: duration_load, dtype: timedelta64[ns]
