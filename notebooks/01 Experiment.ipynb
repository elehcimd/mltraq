# %% [markdown]
# # Define, execute and query an experiment with SQL

# %%
# Imports
from mltraq import create_experiment

# %%
# Create a new experimend, bound to an in-memory SQLite database by default.
experiment = create_experiment("example")
experiment
# Out:
# Experiment(name="example", runs.count=0, id="15592da9-fc8c-4159-8a61-a86607cc2f6f")

# %%
# Add a run and work directly on it.
with experiment.run() as run:
    run.fields.tracked = 5

# %%
# Persist experiment to database.
experiment.persist()
# Out:
# Experiment(name="example", runs.count=1, id="15592da9-fc8c-4159-8a61-a86607cc2f6f")

# %%
# Show stats on runs linked to experiment.
experiment.runs
# Out:
# {UUID('c0490d17-c432-4ca1-99fd-d9fac671cb83'): <mltraq.run.Run at 0x11e90cdd0>}

# %%
# Query experiment with SQL.
experiment.db.query("SELECT id_run, tracked FROM experiment_example")
# Out:
#                                  id_run  tracked
# 0  c0490d17-c432-4ca1-99fd-d9fac671cb83        5
